# %% [markdown]
# In this short script I will teach you how to convert a hyperspectral image into a Pandas DataFrame:
#
# **By**: Yehuda Yungstein

# %%
# Liberies:
# !pip install spectral
from spectral import *
import numpy as np
import pandas as pd
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
def HSI_to_df(path_to_image,list_of_columns):
  img = open_image(path_to_image) # Read the image
  y = img[:,:,:].shape[0] # y axis
  x = img[:,:,:].shape[1] # x axis
  z = img[:,:,:].shape[2] # z axis (bands)
  reshaped= img[:,:,:].reshape(x*y,z)  # Reshape to 2D array
  df = pd.DataFrame(reshaped, columns=list_of_columns) #Convert to df
  
  return df

# %% [markdown]
# ### **Example**

# %%
# Define parameters
path = '/content/drive/MyDrive/Greenwall/HyperSpectral_images/merged/28_07_2022.hdr'
bands = np.arange(1,205,1) # array of band number
# Aplly:
df = HSI_to_df(path,bands)

# Present:
df.head(5)
# Out:
#         1         2         3         4         5         6         7    \
# 0  0.120098  0.115809  0.109375  0.108333  0.114754  0.107790  0.130682
# 1  0.120098  0.115809  0.109375  0.100000  0.100410  0.107790  0.107955
# 2  0.120098  0.115809  0.109375  0.100000  0.100410  0.107790  0.107955
# 3  0.102941  0.102941  0.099432  0.108333  0.107582  0.101449  0.113636
# 4  0.120098  0.115809  0.099432  0.100000  0.100410  0.107790  0.107955
#
#         8         9         10   ...       195       196       197       198  \
# 0  0.121387  0.124365  0.134320  ...  0.253012  0.276899  0.283784  0.291667
# 1  0.111272  0.115482  0.118969  ...  0.253012  0.254747  0.248311  0.253623
# 2  0.111272  0.111041  0.122807  ...  0.242470  0.254747  0.236486  0.253623
# 3  0.111272  0.115482  0.122807  ...  0.242470  0.243671  0.224662  0.253623
# 4  0.106214  0.106599  0.118969  ...  0.231928  0.254747  0.224662  0.240942
#
#         199       200       201       202       203       204
# ...
